# %%
import pandas as rs

# %%
data=rs.read_csv('market_fact.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.2+ KB

# %%
data.shape
# Out:
# (8399, 10)

# %%
data.isna()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0      False    False    False    False  False     False           False
# 1      False    False    False    False  False     False           False
# 2      False    False    False    False  False     False           False
# 3      False    False    False    False  False     False           False
# 4      False    False    False    False  False     False           False
# 5      False    False    False    False  False     False           False
# 6      False    False    False    False  False     False           False
# 7      False    False    False    False  False     False           False
# 8      False    False    False    False  False     False           False
# 9      False    False    False    False  False     False           False
# 10     False    False    False    False  False     False           False
# 11     False    False    False    False  False     False           False
# ...

# %%
data.isna().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
data.isna().sum().sum()
# Out:
# 63

# %%
data.loc[0][3]
# Out:
# 'Cust_1818'

# %%
import pandas as rs

# %%
tab=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv")
tab
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
movie=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user")
movie
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# 5      7|57|M|administrator|91344
# 6      8|36|M|administrator|05201
# 7            9|29|M|student|01002
# 8            10|53|M|lawyer|90703
# 9             11|39|F|other|30329
# 10            12|28|F|other|06405
# 11         13|47|M|educator|29206
# 12        14|45|M|scientist|55106
# 13         15|49|F|educator|97301
# 14    16|21|M|entertainment|10309
# 15       17|30|M|programmer|06355
# 16            18|35|F|other|37212
# 17        19|40|M|librarian|02138
# 18        20|42|F|homemaker|95660
# 19           21|26|M|writer|30068
# 20           22|25|M|writer|40206
# 21           23|30|F|artist|48197
# 22           24|21|F|artist|94533
# 23         25|39|M|engineer|55107
# 24         26|49|M|engineer|21044
# 25        27|40|F|librarian|30030
# ...

# %%
movie.head(10)
# Out:
#       1|24|M|technician|85711
# 0          2|53|F|other|94043
# 1         3|23|M|writer|32067
# 2     4|24|M|technician|43537
# 3          5|33|F|other|15213
# 4      6|42|M|executive|98101
# 5  7|57|M|administrator|91344
# 6  8|36|M|administrator|05201
# 7        9|29|M|student|01002
# 8        10|53|M|lawyer|90703
# 9         11|39|F|other|30329

# %%
movie=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user",sep="|")
movie
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# 5      7  57  M  administrator  91344
# 6      8  36  M  administrator  05201
# 7      9  29  M        student  01002
# 8     10  53  M         lawyer  90703
# 9     11  39  F          other  30329
# 10    12  28  F          other  06405
# 11    13  47  M       educator  29206
# 12    14  45  M      scientist  55106
# 13    15  49  F       educator  97301
# 14    16  21  M  entertainment  10309
# 15    17  30  M     programmer  06355
# 16    18  35  F          other  37212
# 17    19  40  M      librarian  02138
# 18    20  42  F      homemaker  95660
# 19    21  26  M         writer  30068
# 20    22  25  M         writer  40206
# 21    23  30  F         artist  48197
# 22    24  21  F         artist  94533
# 23    25  39  M       engineer  55107
# ...

# %%
movie=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user",sep="|",header=None)
movie
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# 5      6  42  M      executive  98101
# 6      7  57  M  administrator  91344
# 7      8  36  M  administrator  05201
# 8      9  29  M        student  01002
# 9     10  53  M         lawyer  90703
# 10    11  39  F          other  30329
# 11    12  28  F          other  06405
# 12    13  47  M       educator  29206
# 13    14  45  M      scientist  55106
# 14    15  49  F       educator  97301
# 15    16  21  M  entertainment  10309
# 16    17  30  M     programmer  06355
# 17    18  35  F          other  37212
# 18    19  40  M      librarian  02138
# 19    20  42  F      homemaker  95660
# 20    21  26  M         writer  30068
# 21    22  25  M         writer  40206
# 22    23  30  F         artist  48197
# 23    24  21  F         artist  94533
# ...

# %%
col=['Serial NO','Age','Gender','Designation','Empid']
movie=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user",sep="|",header=None)
movie.head(10)
# Out:
#     0   1  2              3      4
# 0   1  24  M     technician  85711
# 1   2  53  F          other  94043
# 2   3  23  M         writer  32067
# 3   4  24  M     technician  43537
# 4   5  33  F          other  15213
# 5   6  42  M      executive  98101
# 6   7  57  M  administrator  91344
# 7   8  36  M  administrator  05201
# 8   9  29  M        student  01002
# 9  10  53  M         lawyer  90703

# %%
movie=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user",sep="|",header=None)
movie[3]
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
# 5          executive
# 6      administrator
# 7      administrator
# 8            student
# 9             lawyer
# 10             other
# 11             other
# 12          educator
# 13         scientist
# 14          educator
# 15     entertainment
# 16        programmer
# 17             other
# 18         librarian
# 19         homemaker
# 20            writer
# 21            writer
# 22            artist
# 23            artist
# 24          engineer
# 25          engineer
# 26         librarian
# 27            writer
# 28        programmer
# 29           student
#            ...
# 913            other
# 914    entertainment
# 915         engineer
# 916          student
# 917        scientist
# 918            other
# 919           artist
# 920          student
# 921    administrator
# 922          student
# 923            other
# 924         salesman
# ...

# %%
movie=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user",sep="|",header=None)
movie[3].unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
movie=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user",sep="|",header=None)
movie[3]=='student'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 913    False
# 914    False
# 915    False
# 916     True
# 917    False
# 918    False
# 919    False
# 920     True
# 921    False
# 922     True
# 923    False
# 924    False
# 925    False
# 926    False
# 927     True
# 928    False
# 929    False
# 930    False
# 931    False
# 932     True
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938     True
# 939    False
# 940     True
# 941    False
# 942     True
# Name: 3, Length: 943, dtype: bool

# %%
movie=rs.read_table("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user",sep="|",header=None)
movie[3]=='entertainment'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 913    False
# 914     True
# 915    False
# 916    False
# 917    False
# 918    False
# 919    False
# 920    False
# 921    False
# 922    False
# 923    False
# 924    False
# 925     True
# 926    False
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# 932    False
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# Name: 3, Length: 943, dtype: bool

# %%
titanic=rs.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv")
titanic.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# name        891 non-null object
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# ticket      891 non-null object
# fare        891 non-null float64
# cabin       204 non-null object
# embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.6+ KB

# %%
titanic['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic['age'].isna().sum()
# Out:
# 177

# %%
t1={'students':['pravalli','vinny','mouni'],
    'sports':['cricket','basketball','tennis'],
    'subject':['c','python','java']}
a1=rs.DataFrame(t1)
a1
# Out:
#        sports  students subject
# 0     cricket  pravalli       c
# 1  basketball     vinny  python
# 2      tennis     mouni    java

# %%
a1.drop_duplicates()
# Out:
#        sports  students subject
# 0     cricket  pravalli       c
# 1  basketball     vinny  python
# 2      tennis     mouni    java

# %%
import matplotlib.pyplot as plt
list1=[1,1.2,1.3,2,2.1,2.2,6,7]
list2=[0,0.7,0.5,1.6,2,2.6,7,9]
plt.scatter(list1,list2)

# %%
s=rs.read_csv("https://raw.githubusercontent.com/nagamounika5/Datasets/master/Advertisement.csv")
s
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...
